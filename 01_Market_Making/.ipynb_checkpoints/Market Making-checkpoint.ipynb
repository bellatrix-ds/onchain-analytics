# %% [markdown]
# # Step 1: List all pools

# %%
# 📊 Data Handling
import pandas as pd
import numpy as np
import requests
from flipside import Flipside
from datetime import datetime


# 📈 Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# ⚙️ Preprocessing & Scaling
from datetime import timedelta
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# 📈 Analysis
import scipy.stats as stats
from sklearn.feature_selection import VarianceThreshold
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
  
# 🧠 Modeling
from sklearn.cluster import KMeans, DBSCAN
import hdbscan
from sklearn.metrics import silhouette_score

# %%
# the list of dex we would like to see on dashboard
df['PLATFORM'].value_counts()
# Out:
# uniswap-v2        45398
# uniswap-v3         7748
# uniswap-v4         3908
# sushiswap          1874
# dodo-v2             782
# balancer            476
# pancakeswap-v2      438
# shibaswap           418
# curve               357
# hashflow-v3         353
# pancakeswap-v3      260
# woofi               137
# kyberswap-v1         27
# verse                22
# kyberswap-v2         17
# fraxswap             11
# dodo-v1              10
# trader-joe-v2         1
# maverick              1
# Name: PLATFORM, dtype: int64

# %% [markdown]
# # Step 0: Based on dex -> indentify pools

# %%
# first we need to have a complete list of pools in specific dex

url = "https://yields.llama.fi/pools"
response = requests.get(url)
all_pools = response.json()['data']

curve_ethereum_pools = [
    pool for pool in all_pools
    if pool['project'] == 'curve-dex' and pool['chain'] == 'Ethereum'
]

df_curve_eth = pd.DataFrame([{
    'chain': pool['chain'],
    'project': pool['project'],
    'pool_name': pool.get('symbol', ''),
    'pool_id': pool['pool'],
    'stablecoin' : pool['stablecoin'],
    'tvlUsd' : pool['tvlUsd']

} for pool in curve_ethereum_pools])

# %%
def format_number(n):
    if n >= 1e9:
        return f"{n/1e9:.2f}B"
    elif n >= 1e6:
        return f"{n/1e6:.2f}M"
    elif n >= 1e3:
        return f"{n/1e3:.2f}K"
    else:
        return str(n)

df_curve_eth['tvlUsd_pretty'] = df_curve_eth['tvlUsd'].apply(format_number)

# %%
df_curve_eth.head(2)
# Out:
#       chain    project      pool_name                               pool_id  \
# 0  Ethereum  curve-dex  DAI-USDC-USDT  25171c4c-1877-449a-9f88-45a9f153ee31
# 1  Ethereum  curve-dex      ETH-STETH  57d30b9c-fc66-4ac2-b666-69ad5f410cce
#
#    stablecoin     tvlUsd tvlUsd_pretty
# 0        True  182497692       182.50M
# 1       False  131390193       131.39M

# %% [markdown]
# # Chart 00: Market Share

# %%
# Filter by stable coins and converting tvl numbers
df_c = df_curve_eth[df_curve_eth['stablecoin']==True]
df_c1 = df_c.groupby(['pool_name','pool_id'])['tvlUsd'].mean().reset_index().sort_values(by='tvlUsd', ascending=False )
df_c1['tvlUsd_pretty'] = df_c1['tvlUsd'].apply(format_number)
df_c1['share'] = round((df_c1['tvlUsd'] / df_c1['tvlUsd'].sum()) * 100)

# %%
# pull out for chart 1
#df_result.to_csv('/Users/bahareh/Desktop/My_Job/BlochChain/Git/onchain-analytics/01_Market_Making/df_tvl.csv')
df_c1[df_c1['share'] > 0]
# Out:
#               pool_name                               pool_id       tvlUsd  \
# 14        DAI-USDC-USDT  25171c4c-1877-449a-9f88-45a9f153ee31  182497692.0
# 42            FRAX-USDE  12ca9565-0369-404e-b209-631305e4012a   67930558.0
# 79          USD0-USD0++  bc58a174-05f8-4e41-8f77-be9c13a614bf   67587904.0
# 89           USDC-RLUSD  e91e23af-9099-45d9-8ba5-ea5b4638e453   51709437.0
# 78           SUSDS-USDT  6f74baf2-48f3-4e4a-ad67-5c056f37e4fa   50650226.0
# 25             DOLA-USR  d78803f4-437f-4ce5-b199-1bae142a185d   40145795.0
# 13           CUSDO-USDC  08d1f13b-5d65-42c5-863d-fcb447dcea75   37137081.0
# 87           USDC-FXUSD  bcc046f9-d980-40d9-80b2-5d5ae5931131   24075919.0
# 70           SDAI-SUSDE  d22deafb-dbb1-417c-b555-cc8c9f4b955a   22067808.0
# 100           USDL-USDC  b92d0d7b-6113-4981-9fa7-fad4d20cad6b   20947559.0
# 23           DOLA-SUSDE  8a3a7995-73b3-4e25-8b5c-82a8841bf720   20466966.0
# 95           USDC-USDTB  fa91389d-ab0f-43e5-8921-9c9a462d97d2   19980497.0
# 80            USD0-USDC  23a68630-c706-4ed3-bb31-92868a15050b   19097207.0
# 8             BOLD-USDC  755529b5-fcf4-4ef0-a7c7-e4f49376706f   18240164.0
# 24           DOLA-SUSDS  b36c0e1b-792f-4fee-8160-a0002c23e1d1   16119623.0
# 61           PYUSD-USDC  14681aee-05c9-4733-acd0-7b2c84616209   15083853.0
# 92            USDC-USDF  3388eabd-fc53-49bf-b358-d1a6dc3c6112   14639088.0
# 15   DAI-USDC-USDT-SUSD  985b3a44-495f-4250-bde3-7b2299036e3e   13468666.0
# 40            FRAX-SDAI  f0eead86-5acd-41a9-93c9-b01766d120e6   11591363.0
# 41            FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1   11230077.0
# 33            EUSD-USDC  3e4081dd-324d-4a46-8aba-01320ac68fa2   11164596.0
# 1      ADAI-AUSDC-AUSDT  e3f861c0-c2b9-4b50-b799-a036a3f11da1   10678543.0
# 58         MSUSD-FRAXBP  62ca653d-a58c-4363-9ffb-b6ceea56a712   10618215.0
# 77          SUSDE-SUSDS  43f6d30e-576d-413d-8c70-6c9d6907ac8c   10207247.0
# 50              GHO-USR  2321794d-15f0-4203-92e9-126cb0012be6   10000697.0
# 88          USDC-LVLUSD  33c78467-864a-4257-b35e-da02dadf3aeb    9240507.0
# 2          ALUSD-FRAXBP  71a56b67-3123-4820-a30f-fac238de441c    8877569.0
# 98            USDE-USDC  a13f0697-d7f1-482b-90c3-21f90725a836    8079048.0
# 60            OUSD-USDC  280bc035-0c3d-4148-99b7-1c43a8cf7a8b    7562579.0
# 69           RUSDY-USDC  39882aee-7fb3-45c2-a39d-9ee60ca09c9b    7396304.0
# 65        REUSD-SFRXUSD  3dde1458-2baa-4b83-a451-c81ac14c8dea    7186770.0
# 19           DOLA-DEUSD  6abb6fba-4303-448c-8abe-70039966b909    6730593.0
# 75           SUSD-SUSDE  5eb84bc0-3c50-473c-adab-2ce33a3682e5    6462390.0
# 44         FRXUSD-SUSDS  d62e6a1e-eb4b-4b22-a919-322a33fba89f    6181798.0
# 54     IDAI-IUSDC-IUSDT  7e218bc2-186c-473d-af0c-415bcdfe392b    5734031.0
# 93            USDC-USDT  e8dda16a-ad63-4925-b234-06861cff79c7    4900573.0
#
#     tvlUsd_pretty  share
# 14        182.50M   20.0
# 42         67.93M    7.0
# 79         67.59M    7.0
# 89         51.71M    6.0
# 78         50.65M    5.0
# 25         40.15M    4.0
# 13         37.14M    4.0
# 87         24.08M    3.0
# 70         22.07M    2.0
# 100        20.95M    2.0
# 23         20.47M    2.0
# 95         19.98M    2.0
# 80         19.10M    2.0
# 8          18.24M    2.0
# 24         16.12M    2.0
# 61         15.08M    2.0
# 92         14.64M    2.0
# 15         13.47M    1.0
# 40         11.59M    1.0
# 41         11.23M    1.0
# 33         11.16M    1.0
# 1          10.68M    1.0
# 58         10.62M    1.0
# 77         10.21M    1.0
# 50         10.00M    1.0
# 88          9.24M    1.0
# 2           8.88M    1.0
# 98          8.08M    1.0
# 60          7.56M    1.0
# 69          7.40M    1.0
# 65          7.19M    1.0
# 19          6.73M    1.0
# 75          6.46M    1.0
# 44          6.18M    1.0
# 54          5.73M    1.0
# 93          4.90M    1.0

# %% [markdown]
# # Chart 1: TVL Over The Time

# %%
import requests

# URL API
url = "https://yields.llama.fi/pools"

# گرفتن داده‌ها
response = requests.get(url)
data = response.json()["data"]

# استخراج projectهایی که chain شون Ethereum هست
ethereum_projects = {pool["project"] for pool in data if pool["chain"] == "Ethereum"}

# چاپ نتیجه
print("📌 Projects on Ethereum:")
for project in sorted(ethereum_projects):
    print("-", project)
# Out:
# 📌 Projects on Ethereum:
# - 1inch-network
# - 3jane
# - aave-v2
# - aave-v3
# - abracadabra-spell
# - across
# - aegis
# - allbridge-classic
# - amphor
# - angle
# - ankr
# - anzen-v2
# - arpa-staking
# - arrakis-v1
# - asymetrix-protocol
# - aura
# - badger-dao
# - bakerfi
# - balancer-v2
# - balancer-v3
# - bancor-v3
# - bedrock-unieth
# - beefy
# - benddao-lending
# - bifrost-liquid-staking
# - binance-staked-eth
# - cat-in-a-box
# - cian-yield-layer
# - clearpool-lending
# - clipper
# - coinbase-wrapped-staked-eth
# - compound-v2
# - compound-v3
# - concentrator
# - conic-finance
# - convex-finance
# - cream-lending
# - crvusd
# - curve-dex
# - curve-llamalend
# - damm-finance
# - dinero-(pxeth)
# - drops
# - dsf.finance
# - ethena-usde
# - ether.fi-stake
# - euler-v2
# - fluid-lending
# - fluid-lite
# - flux-finance
# - folks-finance-xchain
# - fractal-protocol
# - frax
# - frax-ether
# - fraxlend
# - frigg.eco
# - fringe-v1
# - fx-protocol
# - gamma
# - gammaswap
# - gearbox
# - geth
# - goldfinch
# - gravita-protocol
# - harmonix-finance
# - harvest-finance
# - hord
# - hyperdrive
# - impermax-v2
# - index-coop
# - integral
# - ion-protocol
# - ipor-derivatives
# - iq
# - jones-dao
# - kelp
# - landx-finance
# - lido
# - liquid-collective
# - liquity-v1
# - liquity-v2
# - looksrare
# - loopring
# - maverick-v1
# - maverick-v2
# - maxapy
# - meme-dollar
# - merkl
# - meta-pool-eth
# - meth-protocol
# - mev-protocol
# - midas-rwa
# - mmo-finance
# - morpho-aave
# - morpho-blue
# - morpho-compound
# - mover
# - multipli.fi
# - nayms
# - nodedao
# - notional-v3
# - openleverage
# - opyn-squeeth
# - origami-finance
# - origin-arm
# - origin-dollar
# - origin-ether
# - paladin-dullahan
# - paladin-warlord
# - pancakeswap-amm-v3
# - paraspace-lending-v1
# - peapods-finance
# - pendle
# - pods-yield
# - premia-v2
# - prime-protocol
# - prime-staked-eth
# - primex-finance
# - prismalst
# - qidao
# - raft
# - renzo
# - reserve-protocol
# - reservoir-protocol
# - resolv
# - resupply
# - ribbon
# - rocket-pool
# - saddle-finance
# - sandclock
# - sense
# - sherlock
# - sideshift
# - silo-v1
# - size-credit
# - sky-lending
# - smardex
# - smartcredit
# - sparklend
# - spectra-v2
# - stables-labs-usdx
# - stader
# - stafi
# - stake.link-liquid
# - stakedao
# - stakewise-v2
# - stargate-v1
# - stream-finance
# - strike
# - sturdy-v2
# - stusdt
# - sushiswap
# - swell-earn
# - swell-liquid-restaking
# - swell-liquid-staking
# - symbiosis
# - teller
# - thorchain
# - tokemak
# - tokensfarm
# - tranchess-ether
# - uniswap-v2
# - uniswap-v3
# - unsheth
# - upshift
# - usual
# - uwu-lend
# - vesper
# - wasabi
# - wing-finance
# - wise-lending-v2
# - yearn-finance
# - yieldfi
# - yieldnest
# - zeebu
# - zunami-protocol

# %%
import requests
import pandas as pd

# آدرس API
url = "https://yields.llama.fi/pools"

# دریافت داده‌ها
response = requests.get(url)
data = response.json()["data"]

# فیلتر کردن: فقط استخرهای curve-dex و sushiswap روی Ethereum که stablecoin هستند
filtered = [
    pool for pool in data
    if pool["chain"] == "Ethereum"
    and pool["project"] in ["curve-dex", "sushiswap",
                            "balancer-v2","balancer-v3",
                            "uniswap-v2","uniswap-v3","uniswap-v4",
                           "pancakeswap-amm","pancakeswap-amm-v3"]
    and pool.get("stablecoin", False) == True
]

# تبدیل به DataFrame
df = pd.DataFrame([{
    "project": pool["project"],
    "chain": pool["chain"],
    "pool_name": pool.get("symbol", ""),
    "pool_id": pool.get("pool", ""),
    "tvlUsd": pool.get("tvlUsd", 0)
} for pool in filtered])

# %%
df
# Out:
#         project     chain      pool_name  \
# 0     curve-dex  Ethereum  DAI-USDC-USDT
# 1     curve-dex  Ethereum      FRAX-USDE
# 2     curve-dex  Ethereum    USD0-USD0++
# 3    uniswap-v3  Ethereum       DAI-USDC
# 4     curve-dex  Ethereum     USDC-RLUSD
# ..          ...       ...            ...
# 203   curve-dex  Ethereum     FRAX-PYUSD
# 204   curve-dex  Ethereum      FRAX-USDP
# 205   curve-dex  Ethereum    APEUSD-FRAX
# 206   curve-dex  Ethereum     REUSD-USDC
# 207   curve-dex  Ethereum      USDB-USDC
#
#                                   pool_id     tvlUsd
# 0    25171c4c-1877-449a-9f88-45a9f153ee31  182014771
# 1    12ca9565-0369-404e-b209-631305e4012a   67896126
# 2    bc58a174-05f8-4e41-8f77-be9c13a614bf   67313461
# 3    1193ef25-862b-43c1-a545-91bbb9678d30   57282731
# 4    e91e23af-9099-45d9-8ba5-ea5b4638e453   52060334
# ..                                    ...        ...
# 203  d049c13b-0073-44ce-ac92-649d7e64ac04      11322
# 204  ea49024e-942d-4e68-987a-9bd4bbe124c5      11314
# 205  5a2cac97-893f-4124-a15f-e5171cce21f5      10938
# 206  3c7d73df-4886-4184-9d40-d60c09f4d289      10068
# 207  5f996dd0-f86e-44ea-83c2-1fb0bdd421b4      10052
#
# [208 rows x 5 columns]

# %%
# Input pool id based on privouse table

pool_info = {
    "25171c4c-1877-449a-9f88-45a9f153ee31": "DAI-USDC-USDT"
}

start_date = datetime(2025, 5, 12)
end_date = datetime(2025, 6, 12)

results = []

for pool_id, pool_name in pool_info.items():
    url = f"https://yields.llama.fi/chart/{pool_id}"
    r = requests.get(url)
    if r.status_code != 200:
        print(f"❌ Failed for pool {pool_id}")
        continue

    data = r.json().get("data", [])

    for entry in data:
        ts = datetime.fromisoformat(entry["timestamp"].replace("Z", "")).replace(tzinfo=None)
        if start_date <= ts <= end_date:
            results.append({
                "pool_name": pool_name,
                "pool_id": pool_id,
                "timestamp": ts.date(), 
                "tvlUsd": entry.get("tvlUsd", None)
            })

df_result = pd.DataFrame(results)

# %%
# pull out for chart 2
#df_result.to_csv('/Users/bahareh/Desktop/My_Job/BlochChain/Git/onchain-analytics/01_Market_Making/df_tvl.csv')
df_result[df_result['pool_name']=='FRAX-USDC']
# Out:
#      pool_name                               pool_id   timestamp    tvlUsd
# 582  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-12  10718186
# 583  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-13  11148218
# 584  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-14  10850361
# 585  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-15  10749426
# 586  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-16  10671369
# 587  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-17  11030793
# 588  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-18  11533420
# 589  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-19  11038612
# 590  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-20  11425709
# 591  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-21  11742036
# 592  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-22  11269095
# 593  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-23  11283411
# 594  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-24  11319133
# 595  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-25  11831562
# 596  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-26  11670203
# 597  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-27  11804750
# 598  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-28  11204512
# 599  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-29  11468246
# 600  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-30  11248892
# 601  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-05-31  11615641
# 602  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-06-01  11804892
# 603  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-06-02  11409570
# 604  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-06-03  11136791
# 605  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-06-04  11591205
# 606  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-06-05  11267097
# 607  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-06-06  11299655
# 608  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-06-07  11342233
# 609  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-06-08  10765319
# 610  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-06-09  11149486
# 611  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-06-10  11185839
# 612  FRAX-USDC  3f6aa14f-eb0c-4738-bf74-8bc666f7d2b1  2025-06-11  10825857

# %%
df_result['pool_name'].value_counts()
# Out:
# DAI-USDC-USDT         37
# USD0-USD0++           37
# FRAX-SDAI             37
# DAI-USDC-USDT-SUSD    37
# PYUSD-USDC            37
# USDC-USDF             37
# DOLA-SUSDS            37
# USDC-FXUSD            37
# DOLA-SUSDE            37
# USDC-USDTB            37
# USD0-USDC             37
# USDL-USDC             37
# SDAI-SUSDE            37
# DOLA-USR              37
# CUSDO-USDC            37
# SUSDS-USDT            37
# USDC-RLUSD            37
# FRAX-USDE             37
# FRAX-USDC             37
# BOLD-USDC             19
# Name: pool_name, dtype: int64

# %%
df_result[df_result['pool_name'] == "USDC-USDT"]
# Out:
# Empty DataFrame
# Columns: [pool_name, pool_id, timestamp, tvlUsd]
# Index: []

# %%
df_curve_eth[df_curve_eth['pool_name'] == "USDC-USDT"]
# Out:
#        chain    project  pool_name                               pool_id  \
# 79  Ethereum  curve-dex  USDC-USDT  e8dda16a-ad63-4925-b234-06861cff79c7
#
#     stablecoin   tvlUsd tvlUsd_pretty
# 79        True  4900573         4.90M

# %% [markdown]
# # Chart 2: Slippage vs. Trade Size

# %%
# just change the dex name

flipside = Flipside("bfb1c2a7-30de-46af-a084-5b8d9511280c", "https://api-v2.flipsidecrypto.xyz")

sql = """

SELECT
s.PLATFORM as "dex",
s.POOL_NAME as "pool_name",
s.SYMBOL_IN as "token_in",
s.SYMBOL_OUT as "token_out",
CAST(s.BLOCK_TIMESTAMP AS DATE) AS "timestamp" ,
round(avg(ABS(1 - (s.AMOUNT_OUT_USD / s.AMOUNT_IN_USD))) * 100,4) as "Spread",
count(s.TX_HASH) as "swap_count",
SUM(s.AMOUNT_IN_USD + s.AMOUNT_OUT_USD) as "volume",
avg(s.AMOUNT_IN_USD) as "order_size"
from ethereum.defi.ez_dex_swaps s
where s.BLOCK_TIMESTAMP between '2025-05-01' AND TIMESTAMP '2025-06-07'
 and s.AMOUNT_IN_USD > 100
and LOWER(s.PLATFORM) = 'curve'
group by 1,2,3,4,5

"""

query_result_set = flipside.query(sql)
df_c = pd.DataFrame(query_result_set.records)

# %%
df_c = pd.read_csv('df_main.csv')

# %%
# convert date
df_c['timestamp'] = pd.to_datetime(df_c['timestamp'], errors='coerce')
df_c['timestamp'] = df_c['timestamp'].dt.date
df_c['pool_name'] = df_c['token_in'] + "-" + df_c['token_out']

# %%
df_c.head()
# Out:
#      dex                                     pool token_in token_out  \
# 0  curve                          WETH-CRV-crvUSD     WETH    crvUSD
# 1  curve                                OETH-WETH     OETH      WETH
# 2  curve  Curve.fi Factory Plain Pool: msETH/WETH     WETH     msETH
# 3  curve                          WETH-CRV-crvUSD     WETH    crvUSD
# 4  curve                              crvFRAX-STG      STG   crvFRAX
#
#     timestamp  Spread  swap_count     volume     order_size    pool_name
# 0  2025-05-12  0.8117       103.0  772591.50    3752.408447  WETH-crvUSD
# 1  2025-05-30  0.1215        60.0  817920.93    6819.052667    OETH-WETH
# 2  2025-06-05     NaN        39.0        NaN  160670.506923   WETH-msETH
# 3  2025-06-05  1.2249       101.0  732897.30    3655.466238  WETH-crvUSD
# 4  2025-06-05  1.8009         6.0   47149.77    3971.651667  STG-crvFRAX

# %%
df_c.head()
# Out:
#      dex                                     pool token_in token_out  \
# 0  curve                          WETH-CRV-crvUSD     WETH    crvUSD
# 1  curve                                OETH-WETH     OETH      WETH
# 2  curve  Curve.fi Factory Plain Pool: msETH/WETH     WETH     msETH
# 3  curve                          WETH-CRV-crvUSD     WETH    crvUSD
# 4  curve                              crvFRAX-STG      STG   crvFRAX
#
#     timestamp  Spread  swap_count     volume     order_size    pool_name
# 0  2025-05-12  0.8117       103.0  772591.50    3752.408447  WETH-crvUSD
# 1  2025-05-30  0.1215        60.0  817920.93    6819.052667    OETH-WETH
# 2  2025-06-05     NaN        39.0        NaN  160670.506923   WETH-msETH
# 3  2025-06-05  1.2249       101.0  732897.30    3655.466238  WETH-crvUSD
# 4  2025-06-05  1.8009         6.0   47149.77    3971.651667  STG-crvFRAX

# %%
df_result.head()
# Out:
#        pool_name                               pool_id   timestamp     tvlUsd
# 0  DAI-USDC-USDT  25171c4c-1877-449a-9f88-45a9f153ee31  2025-05-01  175508228
# 1  DAI-USDC-USDT  25171c4c-1877-449a-9f88-45a9f153ee31  2025-05-02  175492317
# 2  DAI-USDC-USDT  25171c4c-1877-449a-9f88-45a9f153ee31  2025-05-03  175114027
# 3  DAI-USDC-USDT  25171c4c-1877-449a-9f88-45a9f153ee31  2025-05-04  175365655
# 4  DAI-USDC-USDT  25171c4c-1877-449a-9f88-45a9f153ee31  2025-05-05  175832607

# %%
df_curve_eth
# Out:
#         chain    project         pool_name  \
# 0    Ethereum  curve-dex     DAI-USDC-USDT
# 1    Ethereum  curve-dex         ETH-STETH
# 2    Ethereum  curve-dex     REUSD-SCRVUSD
# 3    Ethereum  curve-dex          ETH-OETH
# 4    Ethereum  curve-dex         FRAX-USDE
# ..        ...        ...               ...
# 397  Ethereum  curve-dex       FETH-FRAXBP
# 398  Ethereum  curve-dex        REUSD-USDC
# 399  Ethereum  curve-dex      WA7A5-CRVUSD
# 400  Ethereum  curve-dex         USDB-USDC
# 401  Ethereum  curve-dex  XSOLVBTC-SOLVBTC
#
#                                   pool_id  stablecoin     tvlUsd tvlUsd_pretty
# 0    25171c4c-1877-449a-9f88-45a9f153ee31        True  182497692       182.50M
# 1    57d30b9c-fc66-4ac2-b666-69ad5f410cce       False  131390193       131.39M
# 2    5c4940c7-c193-440d-b95e-9148d017e12c       False   91558993        91.56M
# 3    18cb2d80-422e-4d0d-a223-66a307f06d8d       False   68205795        68.21M
# 4    12ca9565-0369-404e-b209-631305e4012a        True   67930558        67.93M
# ..                                    ...         ...        ...           ...
# 397  48fbcc9f-a12d-44ad-994a-caa81244bc17       False      10721        10.72K
# 398  3c7d73df-4886-4184-9d40-d60c09f4d289        True      10067        10.07K
# 399  258daf2d-2ccf-4f86-9c63-14a6a5dba998       False      10054        10.05K
# 400  5f996dd0-f86e-44ea-83c2-1fb0bdd421b4        True      10052        10.05K
# 401  a533f1e0-e323-4766-9687-f349e202ae6a       False      10000        10.00K
#
# [402 rows x 7 columns]

# %%
df_c.to_csv('/Users/bahareh/Desktop/metrics.csv')

# %%
data = pd.read_csv('df_main.csv')
data['date'] = pd.to_datetime(data['date']).dt.date
data['Spread'] = pd.to_numeric(data['Spread'], errors='coerce') * 100
data['swap_count'] = pd.to_numeric(data['swap_count'], errors='coerce', downcast='integer')
data['volume'] = pd.to_numeric(data['volume'], errors='coerce')
data['order_size'] = pd.to_numeric(data['order_size'], errors='coerce')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
data['order_size'].plot.box()
plt.title('Distribution of Order Size')
plt.ylabel('Order Size (USD)')
plt.grid(True)
plt.show()

# %%
data.head(2)
# Out:
#   blockchain    dex       pool                                     pool_id  \
# 0   ethereum  curve  USDC-USDT  0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7
# 1   ethereum  curve  USDC-USDT  0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7
#
#          date  Spread  swap_count       volume   order_size    pool_type
# 0  2023-05-25    1.08          98  140920459.0  719020.1165  Stable Pair
# 1  2023-05-24    1.83         111  134852867.4  607471.5597  Stable Pair

# %%
bins = [0, 1_000, 5_000, 10_000, 25_000, 50_000, 100_000, 250_000, 1_000_000, float('inf')]
labels = [
    '≤1k', '1k–5k', '5k–10k', '10k–25k', '25k–50k',
    '50k–100k', '100k–250k', '250k–1M', '>1M'
]

data['order_size_bin'] = pd.cut(data['order_size'], bins=bins, labels=labels)

# %%
data['order_size_bin'].value_counts()
# Out:
# 10k–25k      179
# 25k–50k      118
# 50k–100k     116
# 1k–5k        107
# 5k–10k        98
# 100k–250k     96
# 250k–1M       68
# ≤1k           22
# >1M            6
# Name: order_size_bin, dtype: int64

# %%
plt.figure(figsize=(8, 6))
data['volume'].plot.box()
plt.title('Distribution of volume')
plt.ylabel('volume (USD)')
plt.grid(True)
plt.show()

# %%
import pandas as pd

volume_bins = [
    0,
    1e5,        # 100k
    5e5,        # 500k
    1e6,        # 1M
    5e6,        # 5M
    10e6,       # 10M
    50e6,       # 50M
    100e6,      # 100M
    float('inf')
]

volume_labels = [
    '≤100k', '100k–500k', '500k–1M', '1M–5M', '5M–10M',
    '10M–50M', '50M–100M', '>100M'
]

data['volume_bin'] = pd.cut(data['volume'], bins=volume_bins, labels=volume_labels)

# %%
data['volume_bin'].value_counts()
# Out:
# 1M–5M        240
# 100k–500k    202
# 10M–50M       98
# 500k–1M       90
# ≤100k         68
# 5M–10M        54
# 50M–100M      29
# >100M         29
# Name: volume_bin, dtype: int64

# %%
data['Trade_size'] = data['volume'] / data['swap_count']

# %%
plt.figure(figsize=(8, 6))
data['Trade_size'].plot.box()
plt.title('Distribution of Trade_size')
plt.ylabel('Trade_size')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np

bins = [
    0,
    10_000,
    50_000,
    100_000,
    200_000,
    300_000,
    400_000,
    500_000,
    750_000,
    1_000_000,
    np.inf
]

labels = [
    '≤10k', '10k–50k', '50k–100k', '100k–200k',
    '200k–300k', '300k–400k', '400k–500k',
    '500k–750k', '750k–1M', '>1M'
]

data['trade_size_bin'] = pd.cut(data['Trade_size'], bins=bins, labels=labels)

# %%
data.head()
# Out:
#   blockchain    dex       pool                                     pool_id  \
# 0   ethereum  curve  USDC-USDT  0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7
# 1   ethereum  curve  USDC-USDT  0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7
# 2   ethereum  curve  USDC-USDT  0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7
# 3   ethereum  curve  USDC-USDT  0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7
# 4   ethereum  curve  USDC-USDT  0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7
#
#          date  Spread  swap_count        volume   order_size    pool_type  \
# 0  2023-05-25    1.08          98  1.409205e+08  719020.1165  Stable Pair
# 1  2023-05-24    1.83         111  1.348529e+08  607471.5597  Stable Pair
# 2  2023-06-06    2.24         102  1.228721e+08  602318.2626  Stable Pair
# 3  2023-06-12    2.50         115  1.046169e+08  454873.1544  Stable Pair
# 4  2023-05-12    4.63          90  9.611436e+07  533987.1559  Stable Pair
#
#   order_size_bin volume_bin    Trade_size trade_size_bin
# 0        250k–1M      >100M  1.437964e+06            >1M
# 1        250k–1M      >100M  1.214891e+06            >1M
# 2        250k–1M      >100M  1.204628e+06            >1M
# 3        250k–1M      >100M  9.097117e+05        750k–1M
# 4        250k–1M   50M–100M  1.067937e+06            >1M

# %%
pivot_df = data.pivot_table(index='date', columns='pool', values='Trade_size')

plt.figure(figsize=(14, 6))
pivot_df.plot(figsize=(14, 6), linewidth=1)
plt.title('Trade Size Over Time for Each Pool')
plt.xlabel('Date')
plt.ylabel('Trade Size (USD)')
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), ncol=1, fontsize='small')  
plt.tight_layout()
plt.show()

# %%
# Scoring System

from sklearn.preprocessing import MinMaxScaler

# Step 1: Group by pool and aggregate over time
pool_stats = data.groupby(["blockchain","dex","pool"]).agg({
    "volume": "mean",
    "swap_count": "mean",
    "order_size": "mean",
    "Spread": ["mean", "std"],
    "Trade_size": "mean"
})

# Step 2: Flatten column names
pool_stats.columns = ['volume_mean', 'swap_count_mean', 'order_size_mean', 'spread_mean', 'spread_std', 'trade_size_mean']
pool_stats = pool_stats.reset_index()

# Step 3: Normalize all metrics (min-max scaling)
scaler = MinMaxScaler()
metrics = ['volume_mean', 'swap_count_mean', 'order_size_mean', 'spread_mean', 'spread_std', 'trade_size_mean']

pool_stats_normalized = pool_stats.copy()
pool_stats_normalized[metrics] = scaler.fit_transform(pool_stats[metrics])

# Step 4: Compute MM score (lower spread & lower std better, others higher better)
pool_stats_normalized["mm_score"] = (
    pool_stats_normalized["volume_mean"] * 0.25 +
    pool_stats_normalized["swap_count_mean"] * 0.2 +
    pool_stats_normalized["order_size_mean"] * 0.1 +
    (1 - pool_stats_normalized["spread_mean"]) * 0.25 +
    (1 - pool_stats_normalized["spread_std"]) * 0.1 +
    pool_stats_normalized["trade_size_mean"] * 0.1
)

# Step 5: Rank pools
top_pools = pool_stats_normalized.sort_values(by="mm_score", ascending=False)

# %%
top_pools
# Out:
#    blockchain          dex                 pool  volume_mean  swap_count_mean  \
# 45   ethereum      uniswap            USDC-USDT     1.000000         1.000000
# 6    ethereum     balancer  bb-a-USDC-bb-a-USDT     0.883755         0.073450
# 15   ethereum        curve            USDC-USDT     0.959744         0.305075
# 5    ethereum     balancer   bb-a-DAI-bb-a-USDT     0.264095         0.001409
# 8    ethereum        curve             DAI-USDT     0.286850         0.063282
# 30   ethereum      uniswap             DAI-USDC     0.148882         0.385575
# 10   ethereum        curve            FRAX-USDC     0.106460         0.051981
# 0    ethereum     balancer                DAI-R     0.096795         0.046501
# 16   ethereum        curve          crvUSD-USDC     0.097362         0.134831
# 38   ethereum      uniswap            LUSD-USDC     0.065773         0.171472
# 31   ethereum      uniswap             DAI-USDT     0.041806         0.212669
# 13   ethereum        curve            TUSD-USDC     0.067284         0.043119
# 49   ethereum      uniswap            eUSD-USDC     0.051439         0.006341
# 19   ethereum        curve            eUSD-USDC     0.059951         0.039103
# 21   ethereum  pancakeswap            USDC-USDT     0.060210         0.033290
# 4    ethereum     balancer            USDC-USDT     0.050163         0.011978
# 18   ethereum        curve          crvUSD-USDT     0.054206         0.085660
# 17   ethereum        curve          crvUSD-USDP     0.038431         0.006341
# 7    ethereum        curve             DAI-USDC     0.041902         0.047206
# 1    ethereum     balancer             DAI-USDC     0.034828         0.011474
# 33   ethereum      uniswap            EURA-USDC     0.024059         0.091775
# 9    ethereum        curve            EURA-EURC     0.028821         0.012682
# 35   ethereum      uniswap            FRAX-USDC     0.016438         0.071463
# 12   ethereum        curve             MAI-USDC     0.018403         0.012682
# 37   ethereum      uniswap            GUSD-USDC     0.007931         0.024941
# 25   ethereum      uniswap            BUSD-USDC     0.003692         0.038281
# 26   ethereum      uniswap            BUSD-USDT     0.005119         0.024813
# 36   ethereum      uniswap            FRAX-USDT     0.005145         0.020197
# 3    ethereum     balancer            DOLA-USDC     0.004193         0.018600
# 47   ethereum      uniswap            USDC-XSGD     0.007414         0.032348
# 44   ethereum      uniswap            USDC-USDP     0.002819         0.024519
# 42   ethereum      uniswap            TUSD-USDP     0.001647         0.027478
# 43   ethereum      uniswap            USDC-USDC     0.004206         0.013739
# 41   ethereum      uniswap            TUSD-USDC     0.000000         0.027780
# 23   ethereum    sushiswap            USDC-USDT     0.001786         0.019023
# 2    ethereum     balancer             DAI-USDT     0.002125         0.016909
# 32   ethereum      uniswap            DCHF-USDC     0.002527         0.021665
# 39   ethereum      uniswap             MIM-USDC     0.001591         0.010568
# 46   ethereum      uniswap            USDC-XCHF     0.002061         0.015500
# 28   ethereum      uniswap             DAI-LUSD     0.000501         0.012682
# 29   ethereum      uniswap              DAI-RAI     0.008107         0.042274
# 24   ethereum      uniswap            AUSD-USDT     0.014168         0.022405
# 22   ethereum    sushiswap           ANGLE-EURA     0.022739         0.020291
# 11   ethereum        curve            LUSD-USDC     0.049301         0.000000
# 14   ethereum        curve            TUSD-USDT     0.244045         0.054956
# 20   ethereum  pancakeswap             DAI-USDC     0.011673         0.004227
# 27   ethereum      uniswap             DAI-FRAX     0.003890         0.059183
# 34   ethereum      uniswap           EUROe-USDC     0.000771         0.004227
# 40   ethereum      uniswap             PAR-USDC     0.005783         0.016909
# 48   ethereum      uniswap            USDD-USDT     0.026958         0.000000
# 50   ethereum      uniswap            sUSD-USDC     0.000201         0.004227
#
#     order_size_mean   spread_mean    spread_std  trade_size_mean  mm_score
# 45         0.078049  6.159277e-05  1.258664e-04         0.078040  0.815581
# 6          1.000000  3.880023e-05  7.076546e-05         1.000000  0.785612
# 15         0.408910  8.575804e-06  9.730562e-06         0.408875  0.732726
# 5          0.917338  3.066541e-05  6.667270e-05         0.917022  0.599727
# 8          0.414083  7.659405e-06  9.838885e-06         0.414045  0.517179
# 30         0.033793  4.723493e-05  1.175945e-04         0.033787  0.471070
# 10         0.179939  3.063679e-05  8.336986e-06         0.179897  0.422986
# 0          0.171126  1.951910e-04  2.744192e-04         0.171043  0.417640
# 16         0.076887  2.200346e-05  3.502445e-05         0.076881  0.416674
# 38         0.047616  3.828957e-04  1.304155e-04         0.047609  0.410151
# 31         0.023219  7.914436e-05  8.040992e-04         0.023216  0.407528
# 13         0.112300  1.288552e-04  1.429717e-04         0.112284  0.397857
# 49         0.160652  6.330774e-05  1.084521e-05         0.160619  0.396238
# 19         0.108188  8.608781e-04  1.148044e-03         0.108242  0.394121
# 21         0.111390  6.183665e-06  8.993004e-06         0.111382  0.393985
# 4          0.141016  1.845077e-04  6.052521e-04         0.141008  0.393032
# 18         0.053481  2.742193e-05  4.190374e-05         0.053477  0.391368
# 17         0.122991  2.095258e-05  1.726944e-06         0.122983  0.385468
# 7          0.074940  0.000000e+00  1.080776e-06         0.074933  0.384904
# 1          0.097029  5.129909e-04  3.295711e-03         0.097026  0.379950
# 33         0.027969  3.821951e-03  5.123338e-04         0.028010  0.378961
# 9          0.081572  1.649550e-05  0.000000e+00         0.081551  0.376050
# 35         0.022659  3.082245e-05  9.936354e-06         0.022654  0.372925
# 12         0.052133  8.502533e-04  0.000000e+00         0.052266  0.367364
# 37         0.019212  2.633200e-05  2.693467e-05         0.019205  0.360803
# 25         0.008098  4.545079e-05  4.169399e-05         0.008094  0.360183
# 26         0.011690  6.454999e-05  6.379897e-05         0.011687  0.358558
# 36         0.011351  4.474945e-05  2.883382e-05         0.011347  0.357582
# 3          0.012952  1.037925e-04  3.183587e-05         0.012946  0.357329
# 47         0.015211  1.564146e-02  1.538528e-03         0.015191  0.357299
# 44         0.007880  2.890319e-05  1.821644e-05         0.007877  0.357175
# 42         0.004126  1.025971e-04  5.015044e-05         0.004124  0.356702
# 43         0.012140  6.248331e-05  1.974552e-05         0.012139  0.356210
# 41         0.000000  6.479143e-04  3.433662e-04         0.000000  0.355360
# 23         0.005056  7.417993e-05  7.598552e-07         0.005056  0.355244
# 2          0.006262  5.015345e-05  2.159787e-04         0.006220  0.355127
# 32         0.006294  4.937320e-03  1.551205e-03         0.006292  0.354834
# 39         0.006344  6.129819e-05  1.609511e-05         0.006342  0.353763
# 46         0.005927  5.114968e-03  3.838929e-04         0.005920  0.353483
# 28         0.002175  3.893274e-04  8.736991e-05         0.002174  0.352990
# 29         0.015915  6.770106e-02  2.329681e-02         0.015385  0.344357
# 24         0.032911  2.628378e-01  1.443224e-01         0.036269  0.284799
# 22         0.058319  1.000000e+00  1.000000e+00         0.058342  0.021409
# 11         0.176918  3.179282e-04           NaN         0.177503       NaN
# 14         0.400169  1.008967e-04           NaN         0.399775       NaN
# 20         0.039185  1.099242e-07           NaN         0.039182       NaN
# 27         0.005705  3.138679e-05           NaN         0.005704       NaN
# 34         0.003374  3.103218e-03           NaN         0.003431       NaN
# 40         0.015652  4.031425e-03           NaN         0.015566       NaN
# 48         0.097533  1.258357e-04           NaN         0.097573       NaN
# 50         0.001563  2.860433e-05           NaN         0.001562       NaN

# %%
data
# Out:
#     blockchain          dex       pool  \
# 0     ethereum        curve  USDC-USDT
# 1     ethereum        curve  USDC-USDT
# 2     ethereum        curve  USDC-USDT
# 3     ethereum        curve  USDC-USDT
# 4     ethereum        curve  USDC-USDT
# ..         ...          ...        ...
# 805   ethereum  pancakeswap  USDC-USDT
# 806   ethereum  pancakeswap  USDC-USDT
# 807   ethereum  pancakeswap  USDC-USDT
# 808   ethereum  pancakeswap  USDC-USDT
# 809   ethereum  pancakeswap  USDC-USDT
#
#                                         pool_id        date  Spread  \
# 0    0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7  2023-05-25    1.08
# 1    0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7  2023-05-24    1.83
# 2    0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7  2023-06-06    2.24
# 3    0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7  2023-06-12    2.50
# 4    0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7  2023-05-12    4.63
# ..                                          ...         ...     ...
# 805  0x04c8577958ccc170eb3d2cca76f9d51bc6e42d8f  2023-06-04    2.70
# 806  0x04c8577958ccc170eb3d2cca76f9d51bc6e42d8f  2023-05-30    3.00
# 807  0x04c8577958ccc170eb3d2cca76f9d51bc6e42d8f  2023-05-27    2.38
# 808  0x04c8577958ccc170eb3d2cca76f9d51bc6e42d8f  2023-05-17    2.52
# 809  0x04c8577958ccc170eb3d2cca76f9d51bc6e42d8f  2023-05-12    4.44
#
#      swap_count        volume     order_size    pool_type order_size_bin  \
# 0            98  1.409205e+08  719020.116500  Stable Pair        250k–1M
# 1           111  1.348529e+08  607471.559700  Stable Pair        250k–1M
# 2           102  1.228721e+08  602318.262600  Stable Pair        250k–1M
# 3           115  1.046169e+08  454873.154400  Stable Pair        250k–1M
# 4            90  9.611436e+07  533987.155900  Stable Pair        250k–1M
# ..          ...           ...            ...          ...            ...
# 805          18  1.779271e+05    4942.604141  Stable Pair          1k–5k
# 806          19  4.460822e+06  117399.635000  Stable Pair      100k–250k
# 807          14  1.445850e+06   51644.637290  Stable Pair       50k–100k
# 808          25  4.302271e+06   86041.544910  Stable Pair       50k–100k
# 809          11  1.650343e+06   75007.542120  Stable Pair       50k–100k
#
#     volume_bin    Trade_size trade_size_bin
# 0        >100M  1.437964e+06            >1M
# 1        >100M  1.214891e+06            >1M
# 2        >100M  1.204628e+06            >1M
# 3        >100M  9.097117e+05        750k–1M
# 4     50M–100M  1.067937e+06            >1M
# ..         ...           ...            ...
# 805  100k–500k  9.884842e+03           ≤10k
# 806      1M–5M  2.347801e+05      200k–300k
# 807      1M–5M  1.032750e+05      100k–200k
# 808      1M–5M  1.720908e+05      100k–200k
# 809      1M–5M  1.500312e+05      100k–200k
#
# [810 rows x 14 columns]
